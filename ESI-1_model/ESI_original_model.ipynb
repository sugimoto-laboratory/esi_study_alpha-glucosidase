# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import optuna
import shap
import pickle
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
class DataProcessor:
    def __init__(self, all_data, desc_set, object_variable, split_seed):
        self.desc_set = desc_set
        self.object_variable = object_variable
        self.split_seed = split_seed
        self.x_data, self.y_data ,self.x_train, self.x_test, self.y_train, self.y_test = self.prepare_datasets(all_data)
        self.X_data, self.Y_data, self.X_train, self.X_test, self.Y_train, self.Y_test = self.normalize_data()
        self.dall, self.dtrain, self.dtest, self.evals = self.convert_data()

    def prepare_datasets(self, all_data):
        x_data = all_data[self.desc_set]
        y_data = pd.DataFrame(all_data[self.object_variable])
        
        train, test = train_test_split(all_data, test_size=0.2, random_state=self.split_seed)
        x_train = train[self.desc_set]
        y_train = pd.DataFrame(train[self.object_variable])
        x_test = test[self.desc_set]
        y_test = pd.DataFrame(test[self.object_variable])

        return x_data, y_data, x_train, x_test, y_train, y_test

    def normalize_data(self):
        self.mean_data_x = self.x_data.mean()
        self.std_data_x = self.x_data.std()
        self.mean_data_y = self.y_data.mean()
        self.std_data_y = self.y_data.std()
        X_data = (self.x_data - self.mean_data_x) / self.std_data_x
        Y_data = (self.y_data - self.mean_data_y) / self.std_data_y
        
        self.mean_train_x = self.x_train.mean()
        self.std_train_x = self.x_train.std()
        self.mean_test_x = self.x_test.mean()
        self.std_test_x = self.x_test.std()
        self.mean_train_y = self.y_train.mean()
        self.std_train_y = self.y_train.std()
        self.mean_test_y = self.y_test.mean()
        self.std_test_y = self.y_test.std()
        X_train = (self.x_train - self.mean_train_x) / self.std_train_x
        X_test = (self.x_test - self.mean_test_x) / self.std_test_x
        Y_train = (self.y_train - self.mean_train_y) / self.std_train_y
        Y_test = (self.y_test - self.mean_test_y) / self.std_test_y
        
        return X_data, Y_data, X_train, X_test, Y_train, Y_test
    
    def convert_data(self):
        dall = xgb.DMatrix(self.X_data, label=self.Y_data)
        dtrain = xgb.DMatrix(self.X_train, label=self.Y_train)
        dtest = xgb.DMatrix(self.X_test, label=self.Y_test)
        evals = [(dtest, 'eval'), (dtrain, 'train')]
        
        return dall, dtrain, dtest, evals

# %%
class Optimization:
    def __init__(self, data_processor, directory, basename, n_trials=300):
        self.dp = data_processor
        self.directory = directory
        self.basename = basename
        self.n_trials = n_trials
 
    def objective(self, trial):
        
        params = {
            "verbosity": 0,
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster":  "gbtree",
            'n_estimators' : 10000,
            'base_score' : float(self.dp.Y_data.mean().values),
            'max_depth': trial.suggest_int('max_depth', 2, 6),
            'max_leaves': trial.suggest_int('max_leaves', 2, 7),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1),
            'colsample_byrevel': trial.suggest_float('colsample_bylevel', 0.1, 1),
            'colsample_bybode': trial.suggest_float('colsample_bynode', 0.1, 1),
            'subsample': trial.suggest_float('subsample', 0, 1),
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 10, log=True),
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 10, log=True),
            "leraning_rate" : trial.suggest_float("leraning_rate", 1e-4, 10, log=False),
            "gamma" : trial.suggest_float("gamma", 0.1, 10, log=False),
        }

        cv_results = xgb.cv(
            params = params,
            dtrain = self.dp.dall,
            num_boost_round=10000,
            seed=0,
            nfold=5, # CVの分割数
            metrics={"rmse"},
            early_stopping_rounds=150,
            shuffle=True,
        )
        
        return cv_results["test-rmse-mean"].mean()

    def optimize_parameters(self):
        max_depth = 4
        max_leaves = 6
        colsample_bytree = 0.8362947158012995
        colsample_bylevel = 0.9410318834111969
        colsample_bynode = 0.5275426570755766
        subsample = 0.7980991478396294
        reg_lambda = 0.08175964142376442
        reg_alpha = 2.5425349978134
        leraning_rate = 0.403459404172576
        gamma = 0.10333420649951462
        
        start_params = {
            'objective': 'reg:squarederror',
            'eval_metric': 'rmse',
            "booster":  "gbtree",
            'verbosity' : 0,
            'random_state' : 0,
            'n_estimators' : 10000,
            'base_score' : float(self.dp.Y_data.mean().values), 
            'max_depth': max_depth, 
            'max_leaves':max_leaves,
            'colsample_bytree': colsample_bytree,
            'colsample_byrevel': colsample_bylevel,
            'colsample_bynode': colsample_bynode,
            'subsample': subsample,
            "reg_lambda": reg_lambda,
            "reg_alpha": reg_alpha,
            "leraning_rate" : leraning_rate,
            "gamma" : gamma,
        }
        self.start_params = start_params
        # ベイズ最適化実行
        study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner())
        study.enqueue_trial(self.start_params)
        study.optimize(lambda trial: self.objective(trial), n_trials=self.n_trials)
        self.opt_params = study.best_params
        
        with open(f"{self.directory}/{self.basename}_best_params", 'w') as f:
            for k, v in self.opt_params.items():
                print(f'{k} = {v}', file=f)

# %%
class Modeling:
    def __init__(self, data_processor, opt, directory, basename, n_seed=100):
        self.dp = data_processor
        self.opt = opt
        self.directory = directory
        self.basename = basename
        self.n_seed = n_seed
    
    def search_best_model(self, i):
        
        #複数のseed値で探索
        best_score = 0
        best_seed = 0
        for seed in range(self.n_seed):
            base_params = {"verbosity": 0,
                "objective": "reg:squarederror",
                "eval_metric": "rmse",
                "booster":  "gbtree",
                'n_estimators' : 10000,
                'random_state' : int(seed)
                }
            
            all_params = dict(**base_params, **self.opt.opt_params) 
            model = xgb.train(params=all_params,
                              dtrain=self.dp.dtrain,
                              num_boost_round=10000,
                              early_stopping_rounds=100, 
                              evals=self.dp.evals, 
                              verbose_eval=False
                             )
            
            
            #Predict
            train_pred = pd.DataFrame(model.predict(self.dp.dtrain), columns=[self.dp.object_variable])
            test_pred = pd.DataFrame(model.predict(self.dp.dtest), columns=[self.dp.object_variable])
            # R2値を表示
            r2_train = r2_score(self.dp.Y_train, train_pred).round(4)
            r2_test = r2_score(self.dp.Y_test, test_pred).round(4)
            
            if r2_test >= best_score:
                best_score = r2_test
                best_seed = seed
                best_params = all_params
                self.best_params = best_params
            print(f'Spliting Data {i} : seed {seed} done, best_seed = {best_seed}, best_score = {best_score}')

        with open(f"{self.directory}/{self.basename}_"+str(i), 'w') as f:
            for k, v in self.best_params.items():
                print(f'{k} = {v}', file=f)

        return best_params

# %%
class ModelSaver:
    def __init__(self, modeler, data_processor, directory, basename):
        self.dp = data_processor
        self.model = modeler
        self.directory = directory
        self.basename = basename

    def save_best_model(self, i):
        best_model = xgb.train(params=self.model.best_params,
                           dtrain=self.dp.dtrain,
                           num_boost_round=10000,
                           early_stopping_rounds=100,
                           evals=self.dp.evals, 
                           verbose_eval=False,
                          )
        with open(f"{self.directory}/{self.basename}_model_{i}.pickle", mode='wb') as f:
            pickle.dump(best_model, f)
        best_model.save_model(f"{self.directory}/{self.basename}_model_{i}.json")
        
        train_pred = pd.DataFrame(best_model.predict(self.dp.dtrain), columns=['pIC50'])
        test_pred = pd.DataFrame(best_model.predict(self.dp.dtest), columns=['pIC50'])
        r2_train = r2_score(self.dp.Y_train, train_pred).round(4)
        r2_test = r2_score(self.dp.Y_test, test_pred).round(4)
        self.train_pred = train_pred
        self.test_pred = test_pred
        self.r2_train = r2_train
        self.r2_test = r2_test
        self.best_model = best_model
        
        
        return train_pred, test_pred, r2_train, r2_test

    def save_yyplot(self, i):
        m1, s1 = self.dp.mean_train_y, self.dp.std_train_y
        m2, s2 = self.dp.mean_test_y, self.dp.std_test_y
        # 説明変数と目的変数のデータ点の散布図をプロット
        fig = plt.figure(figsize=(5,5))
        fig.suptitle(" ", fontsize=15)
        s=np.linspace(2.5, 7.5, 50)
        t = s
        plt.plot(s, t, color='k')
        #scatter
        plt.scatter(m1 + self.train_pred*s1, m1 + self.dp.Y_train*s1, color='blue', marker='.' , label='training set')
        plt.scatter(m2 + self.test_pred*s2, m2 + self.dp.Y_test*s2, color='red', marker='.' , label='test set')
        plt.legend(loc=2, fontsize=14)
        plt.xlabel('pIC50 Pred')  # x軸のラベル
        plt.ylabel('pIC50 Expt')  # y軸のラベル
        #plt.xlim(2.5, 7.5)
        #plt.ylim(2.5, 7.5)
        text1 = f'r2_train={self.r2_train}'
        text2 = f'r2_test={self.r2_test}'
        plt.text(4.9, 3, text1, fontsize="xx-large", color='blue')
        plt.text(4.9, 2.5, text2, fontsize="xx-large", color='red')
        plt.savefig(f"{self.directory}/yy_plot_{self.basename}_"+str(i)+".png")

    def save_shap(self, i):
        # SHAP値を計算するためのexplainerを作成
        explainer = shap.TreeExplainer(
            model = self.best_model,  # 学習済みモデル
            feature_perturbation="interventional"  # 推奨
            )
        # SHAP値を計算
        shap_values = explainer(self.dp.X_train, self.dp.Y_train)

        # 棒グラフで重要度を可視化
        fig2 = plt.figure()   #新しいウィンドウを描画
        fig2.subplots()
        shap.plots.bar(shap_values=shap_values, max_display=10, show=False)
        fig2.savefig(f"{self.directory}/shap_bar_{self.basename}_"+str(i)+".png") # 画像を保存
        
        fig3 = plt.figure()   #新しいウィンドウを描画
        fig3.subplots()
        shap.plots.beeswarm(shap_values=shap_values, max_display=10, show=False)
        fig3.savefig(f"{self.directory}/shap_beeswarm_{self.basename}_"+str(i)+".png", bbox_inches='tight') 
        plt.clf()
        plt.close()

# %%
def main():
    desc_set = ['rUV', 'rex', 'rfreq', 'rIR', 'rorb', 'IPv', 'C-S0', 'S0-C', 'EAv', 'A-S0', 'S0-A',
                'STv', 'T1-S0', 'S0-T1', 'Esolv', 'mu', 'Vmol', 'B1', 'B2', 'B3', 'MW']
    object_variable = "pIC50"
    directory = "model_result"
    basename = "ESI_original"
    train_score = []
    test_score =[]
    bayes_n_trials = 1000
    n_seed = 1
    seed_list = pd.read_csv("../datasets/split_seed_result.csv")["seed"]
    all_data = pd.read_csv("../datasets/231113_a-glucosidase_dataset_all.csv")
    if not os.path.isdir(f"{directory}"):
        os.makedirs(f"{directory}")

    #ここで全データでベイズ最適化
    all_data_processor = DataProcessor(all_data, desc_set, object_variable, split_seed=0)
    opt = Optimization(all_data_processor, directory, basename, n_trials=bayes_n_trials)
    opt.optimize_parameters()
    
    for i, split_seed in enumerate(seed_list):
        data_processor = DataProcessor(all_data, desc_set, object_variable, split_seed=split_seed)
        modeler = Modeling(data_processor,opt, directory, basename, n_seed=n_seed)
        modeler.search_best_model(i)

        saver = ModelSaver(modeler, data_processor, directory, basename)
        _, _, r2_train, r2_test = saver.save_best_model(i)
        train_score.append(r2_train)
        test_score.append(r2_test)
        
        # 図の保存
        saver.save_yyplot(i)
        saver.save_shap(i)
        plt.clf()
        plt.close()

    train_score_df = pd.DataFrame(train_score)
    test_score_df = pd.DataFrame(test_score)
    score_df = pd.concat([train_score_df, test_score_df], axis=1)
    score_df.columns = ['r2_train','r2_test']
    score_df.to_csv(f'{directory}/all_score.csv')
    

if __name__ == "__main__":
    main()
# Out:
# [I 2023-12-06 23:39:38,484] A new study created in memory with name: no-name-63208c05-21a8-45e7-a0de-262bfd13b4b4
# enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# create_trial is experimental (supported from v2.0.0). The interface can change in the future.
# add_trial is experimental (supported from v2.0.0). The interface can change in the future.
# [I 2023-12-06 23:39:40,813] Trial 0 finished with value: 0.6501924289734219 and parameters: {'max_depth': 4, 'max_leaves': 4, 'colsample_bytree': 0.6497823932676446, 'colsample_bylevel': 0.6443548851430514, 'colsample_bynode': 0.7732425091215354, 'subsample': 0.6082139601485789, 'reg_lambda': 9.42767838143831, 'reg_alpha': 1.8062553402037316, 'leraning_rate': 0.30543419651343584, 'gamma': 0.10106389400877043}. Best is trial 0 with value: 0.6501924289734219.
# Spliting Data 0 : seed 0 done, best_seed = 0, best_score = 0.4155
# Spliting Data 1 : seed 0 done, best_seed = 0, best_score = 0.4133
# Spliting Data 2 : seed 0 done, best_seed = 0, best_score = 0.5674
# Spliting Data 3 : seed 0 done, best_seed = 0, best_score = 0.5067
# Spliting Data 4 : seed 0 done, best_seed = 0, best_score = 0.5646
# Spliting Data 5 : seed 0 done, best_seed = 0, best_score = 0.5742
# Spliting Data 6 : seed 0 done, best_seed = 0, best_score = 0.4896
# Spliting Data 7 : seed 0 done, best_seed = 0, best_score = 0.5878
# Spliting Data 8 : seed 0 done, best_seed = 0, best_score = 0.5845
# Spliting Data 9 : seed 0 done, best_seed = 0, best_score = 0.5021
# Spliting Data 10 : seed 0 done, best_seed = 0, best_score = 0.4314
# Spliting Data 11 : seed 0 done, best_seed = 0, best_score = 0.5952
# Spliting Data 12 : seed 0 done, best_seed = 0, best_score = 0.5329
# Spliting Data 13 : seed 0 done, best_seed = 0, best_score = 0.5505
# Spliting Data 14 : seed 0 done, best_seed = 0, best_score = 0.6037
# Spliting Data 15 : seed 0 done, best_seed = 0, best_score = 0.5865
# Spliting Data 16 : seed 0 done, best_seed = 0, best_score = 0.5342
# Spliting Data 17 : seed 0 done, best_seed = 0, best_score = 0.651
# Spliting Data 18 : seed 0 done, best_seed = 0, best_score = 0.403
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Spliting Data 19 : seed 0 done, best_seed = 0, best_score = 0.5492
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Spliting Data 20 : seed 0 done, best_seed = 0, best_score = 0.5849
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Spliting Data 21 : seed 0 done, best_seed = 0, best_score = 0.565
# Spliting Data 22 : seed 0 done, best_seed = 0, best_score = 0.558
# Spliting Data 23 : seed 0 done, best_seed = 0, best_score = 0.5281
# Spliting Data 24 : seed 0 done, best_seed = 0, best_score = 0.442
# Spliting Data 25 : seed 0 done, best_seed = 0, best_score = 0.6823
# Spliting Data 26 : seed 0 done, best_seed = 0, best_score = 0.5118
# Spliting Data 27 : seed 0 done, best_seed = 0, best_score = 0.3714
# Spliting Data 28 : seed 0 done, best_seed = 0, best_score = 0.6185
# Spliting Data 29 : seed 0 done, best_seed = 0, best_score = 0.6115
# Spliting Data 30 : seed 0 done, best_seed = 0, best_score = 0.4388
# Spliting Data 31 : seed 0 done, best_seed = 0, best_score = 0.3513
# Spliting Data 32 : seed 0 done, best_seed = 0, best_score = 0.63
# Spliting Data 33 : seed 0 done, best_seed = 0, best_score = 0.6709
# Spliting Data 34 : seed 0 done, best_seed = 0, best_score = 0.5301
# Spliting Data 35 : seed 0 done, best_seed = 0, best_score = 0.5715
# Spliting Data 36 : seed 0 done, best_seed = 0, best_score = 0.6504
# Spliting Data 37 : seed 0 done, best_seed = 0, best_score = 0.5667
# Spliting Data 38 : seed 0 done, best_seed = 0, best_score = 0.458
# Spliting Data 39 : seed 0 done, best_seed = 0, best_score = 0.5622
# Spliting Data 40 : seed 0 done, best_seed = 0, best_score = 0.3814
# Spliting Data 41 : seed 0 done, best_seed = 0, best_score = 0.6018
# Spliting Data 42 : seed 0 done, best_seed = 0, best_score = 0.3473
# Spliting Data 43 : seed 0 done, best_seed = 0, best_score = 0.5792
# Spliting Data 44 : seed 0 done, best_seed = 0, best_score = 0.6081
# Spliting Data 45 : seed 0 done, best_seed = 0, best_score = 0.4781
# Spliting Data 46 : seed 0 done, best_seed = 0, best_score = 0.3463
# Spliting Data 47 : seed 0 done, best_seed = 0, best_score = 0.473
# Spliting Data 48 : seed 0 done, best_seed = 0, best_score = 0.5422
# Spliting Data 49 : seed 0 done, best_seed = 0, best_score = 0.3436
# Spliting Data 50 : seed 0 done, best_seed = 0, best_score = 0.5036
# Spliting Data 51 : seed 0 done, best_seed = 0, best_score = 0.5359
# Spliting Data 52 : seed 0 done, best_seed = 0, best_score = 0.6
# Spliting Data 53 : seed 0 done, best_seed = 0, best_score = 0.6526
# Spliting Data 54 : seed 0 done, best_seed = 0, best_score = 0.5224
# Spliting Data 55 : seed 0 done, best_seed = 0, best_score = 0.5167
# Spliting Data 56 : seed 0 done, best_seed = 0, best_score = 0.4569
# Spliting Data 57 : seed 0 done, best_seed = 0, best_score = 0.584
# Spliting Data 58 : seed 0 done, best_seed = 0, best_score = 0.5164
# Spliting Data 59 : seed 0 done, best_seed = 0, best_score = 0.4716
# Spliting Data 60 : seed 0 done, best_seed = 0, best_score = 0.6353
# Spliting Data 61 : seed 0 done, best_seed = 0, best_score = 0.2893
# Spliting Data 62 : seed 0 done, best_seed = 0, best_score = 0.595
# Spliting Data 63 : seed 0 done, best_seed = 0, best_score = 0.6163
# Spliting Data 64 : seed 0 done, best_seed = 0, best_score = 0.4829
# Spliting Data 65 : seed 0 done, best_seed = 0, best_score = 0.5718
# Spliting Data 66 : seed 0 done, best_seed = 0, best_score = 0.4735
# Spliting Data 67 : seed 0 done, best_seed = 0, best_score = 0.5456
# Spliting Data 68 : seed 0 done, best_seed = 0, best_score = 0.4578
# Spliting Data 69 : seed 0 done, best_seed = 0, best_score = 0.493
# Spliting Data 70 : seed 0 done, best_seed = 0, best_score = 0.6169
# Spliting Data 71 : seed 0 done, best_seed = 0, best_score = 0.2768
# Spliting Data 72 : seed 0 done, best_seed = 0, best_score = 0.5356
# Spliting Data 73 : seed 0 done, best_seed = 0, best_score = 0.5812
# Spliting Data 74 : seed 0 done, best_seed = 0, best_score = 0.4784
# Spliting Data 75 : seed 0 done, best_seed = 0, best_score = 0.5561
# Spliting Data 76 : seed 0 done, best_seed = 0, best_score = 0.5094
# Spliting Data 77 : seed 0 done, best_seed = 0, best_score = 0.4363
# Spliting Data 78 : seed 0 done, best_seed = 0, best_score = 0.3801
# Spliting Data 79 : seed 0 done, best_seed = 0, best_score = 0.4831
# Spliting Data 80 : seed 0 done, best_seed = 0, best_score = 0.4234
# Spliting Data 81 : seed 0 done, best_seed = 0, best_score = 0.3546
# Spliting Data 82 : seed 0 done, best_seed = 0, best_score = 0.5143
# Spliting Data 83 : seed 0 done, best_seed = 0, best_score = 0.468
# Spliting Data 84 : seed 0 done, best_seed = 0, best_score = 0.4892
# Spliting Data 85 : seed 0 done, best_seed = 0, best_score = 0.4205
# Spliting Data 86 : seed 0 done, best_seed = 0, best_score = 0.5768
# Spliting Data 87 : seed 0 done, best_seed = 0, best_score = 0.5014
# Spliting Data 88 : seed 0 done, best_seed = 0, best_score = 0.608
# Spliting Data 89 : seed 0 done, best_seed = 0, best_score = 0.4333
# Spliting Data 90 : seed 0 done, best_seed = 0, best_score = 0.4604
# Spliting Data 91 : seed 0 done, best_seed = 0, best_score = 0.531
# Spliting Data 92 : seed 0 done, best_seed = 0, best_score = 0.3596
# Spliting Data 93 : seed 0 done, best_seed = 0, best_score = 0.4475
# Spliting Data 94 : seed 0 done, best_seed = 0, best_score = 0.5823
# Spliting Data 95 : seed 0 done, best_seed = 0, best_score = 0.6117
# Spliting Data 96 : seed 0 done, best_seed = 0, best_score = 0.3586
# Spliting Data 97 : seed 0 done, best_seed = 0, best_score = 0.5616
# Spliting Data 98 : seed 0 done, best_seed = 0, best_score = 0.4683
# Spliting Data 99 : seed 0 done, best_seed = 0, best_score = 0.5413
# Spliting Data 100 : seed 0 done, best_seed = 0, best_score = 0.6272
# Spliting Data 101 : seed 0 done, best_seed = 0, best_score = 0.4922
# Spliting Data 102 : seed 0 done, best_seed = 0, best_score = 0.5798
# Spliting Data 103 : seed 0 done, best_seed = 0, best_score = 0.4562
# Spliting Data 104 : seed 0 done, best_seed = 0, best_score = 0.4532
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qv/cp3ld5x909g1rq13yk4q7ybr0000gn/T/ipykernel_5036/2351147263.py in <cell line: 44>()
#      43
#      44 if __name__ == "__main__":
# ---> 45     main()
#
# /var/folders/qv/cp3ld5x909g1rq13yk4q7ybr0000gn/T/ipykernel_5036/2351147263.py in main()
#      22         data_processor = DataProcessor(all_data, desc_set, object_variable, split_seed=split_seed)
#      23         modeler = Modeling(data_processor,opt, directory, basename, n_seed=n_seed)
# ---> 24         modeler.search_best_model(i)
#      25
#      26         saver = ModelSaver(modeler, data_processor, directory, basename)
#
# /var/folders/qv/cp3ld5x909g1rq13yk4q7ybr0000gn/T/ipykernel_5036/444150099.py in search_best_model(self, i)
#      22
#      23             all_params = dict(**base_params, **self.opt.opt_params)
# ---> 24             model = xgb.train(params=all_params,
#      25                               dtrain=self.dp.dtrain,
#      26                               num_boost_round=10000,
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     184             break
#     185         bst.update(dtrain, i, obj)
# --> 186         if cb_container.after_iteration(bst, i, dtrain, evals):
#     187             break
#     188
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/xgboost/callback.py in after_iteration(self, model, epoch, dtrain, evals)
#     238             for _, name in evals:
#     239                 assert name.find('-') == -1, 'Dataset name should not contain `-`'
# --> 240             score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     241             splited = score.split()[1:]  # into datasets
#     242             # split up `test-error:0.1234`
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/xgboost/core.py in eval_set(self, evals, iteration, feval, output_margin)
#    1987         msg = ctypes.c_char_p()
#    1988         _check_call(
# -> 1989             _LIB.XGBoosterEvalOneIter(
#    1990                 self.handle,
#    1991                 ctypes.c_int(iteration),
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7faf0be8e320> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297             if bbox_inches:
#    2298                 if bbox_inches == "tight":
# -> 2299                     bbox_inches = self.figure.get_tightbbox(
#    2300                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2301                     if pad_inches is None:
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1630
#    1631         for a in artists:
# -> 1632             bbox = a.get_tightbbox(renderer)
#    1633             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1634                 bb.append(bbox)
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1103         ticks_to_draw = self._update_ticks()
#    1104
# -> 1105         self._update_label_position(renderer)
#    1106
#    1107         # go back to just this axis's tick labels
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2357                 spine = self.axes.spines['left']
#    2358                 spinebbox = spine.get_transform().transform_path(
# -> 2359                     spine.get_path()).get_extents()
#    2360             except KeyError:
#    2361                 # use axes if spine doesn't exist
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     631             xys = np.concatenate(xys)
#     632         if len(xys):
# --> 633             return Bbox([xys.min(axis=0), xys.max(axis=0)])
#     634         else:
#     635             return Bbox.null()
#
# ~/opt/anaconda3/envs/ml_env/lib/python3.10/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      45
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
seed_list = pd.read_csv("../datasets/split_seed_result.csv")["seed"]
seed_list
