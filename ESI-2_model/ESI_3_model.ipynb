# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import optuna
import shap
import pickle
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
class DataProcessor:
    def __init__(self, all_data, desc_set, object_variable, split_seed):
        self.desc_set = desc_set
        self.object_variable = object_variable
        self.split_seed = split_seed
        self.x_data, self.y_data ,self.x_train, self.x_test, self.y_train, self.y_test = self.prepare_datasets(all_data)
        self.X_data, self.Y_data, self.X_train, self.X_test, self.Y_train, self.Y_test = self.normalize_data()
        self.dall, self.dtrain, self.dtest, self.evals = self.convert_data()

    def prepare_datasets(self, all_data):
        x_data = all_data[self.desc_set]
        y_data = pd.DataFrame(all_data[self.object_variable])
        
        train, test = train_test_split(all_data, test_size=0.2, random_state=self.split_seed)
        x_train = train[self.desc_set]
        y_train = pd.DataFrame(train[self.object_variable])
        x_test = test[self.desc_set]
        y_test = pd.DataFrame(test[self.object_variable])

        return x_data, y_data, x_train, x_test, y_train, y_test

    def normalize_data(self):
        self.mean_data_x = self.x_data.mean()
        self.std_data_x = self.x_data.std()
        self.mean_data_y = self.y_data.mean()
        self.std_data_y = self.y_data.std()
        X_data = (self.x_data - self.mean_data_x) / self.std_data_x
        Y_data = (self.y_data - self.mean_data_y) / self.std_data_y
        
        self.mean_train_x = self.x_train.mean()
        self.std_train_x = self.x_train.std()
        self.mean_test_x = self.x_test.mean()
        self.std_test_x = self.x_test.std()
        self.mean_train_y = self.y_train.mean()
        self.std_train_y = self.y_train.std()
        self.mean_test_y = self.y_test.mean()
        self.std_test_y = self.y_test.std()
        X_train = (self.x_train - self.mean_train_x) / self.std_train_x
        X_test = (self.x_test - self.mean_test_x) / self.std_test_x
        Y_train = (self.y_train - self.mean_train_y) / self.std_train_y
        Y_test = (self.y_test - self.mean_test_y) / self.std_test_y
        
        return X_data, Y_data, X_train, X_test, Y_train, Y_test
    
    def convert_data(self):
        dall = xgb.DMatrix(self.X_data, label=self.Y_data)
        dtrain = xgb.DMatrix(self.X_train, label=self.Y_train)
        dtest = xgb.DMatrix(self.X_test, label=self.Y_test)
        evals = [(dtest, 'eval'), (dtrain, 'train')]
        
        return dall, dtrain, dtest, evals

# %%
class Optimization:
    def __init__(self, data_processor, directory, basename, n_trials=300):
        self.dp = data_processor
        self.directory = directory
        self.basename = basename
        self.n_trials = n_trials
 
    def objective(self, trial):
        
        params = {
            "verbosity": 0,
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster":  "gbtree",
            'n_estimators' : 10000,
            'base_score' : float(self.dp.Y_data.mean().values),
            'max_depth': trial.suggest_int('max_depth', 2, 6),
            'max_leaves': trial.suggest_int('max_leaves', 2, 7),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1),
            'colsample_byrevel': trial.suggest_float('colsample_bylevel', 0.1, 1),
            'colsample_bybode': trial.suggest_float('colsample_bynode', 0.1, 1),
            'subsample': trial.suggest_float('subsample', 0, 1),
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 10, log=True),
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 10, log=True),
            "leraning_rate" : trial.suggest_float("leraning_rate", 1e-4, 10, log=False),
            "gamma" : trial.suggest_float("gamma", 0.1, 10, log=False),
        }

        cv_results = xgb.cv(
            params = params,
            dtrain = self.dp.dall,
            num_boost_round=10000,
            seed=0,
            nfold=5, # CVの分割数
            metrics={"rmse"},
            early_stopping_rounds=150,
            shuffle=True,
        )
        
        return cv_results["test-rmse-mean"].mean()

    def optimize_parameters(self):
        max_depth = 6
        max_leaves = 7
        colsample_bytree = 0.6765954769686744
        colsample_bylevel = 0.6499590666325743
        colsample_bynode = 0.6365965428978061
        subsample = 0.9057028227580022
        reg_lambda = 8.038853110510981
        reg_alpha = 0.027527442350278545
        leraning_rate = 3.5567452676018396
        gamma = 0.10011594944813659
        
        start_params = {
            'objective': 'reg:squarederror',
            'eval_metric': 'rmse',
            "booster":  "gbtree",
            'verbosity' : 0,
            'random_state' : 0,
            'n_estimators' : 10000,
            'base_score' : float(self.dp.Y_data.mean().values), 
            'max_depth': max_depth, 
            'max_leaves':max_leaves,
            'colsample_bytree': colsample_bytree,
            'colsample_byrevel': colsample_bylevel,
            'colsample_bynode': colsample_bynode,
            'subsample': subsample,
            "reg_lambda": reg_lambda,
            "reg_alpha": reg_alpha,
            "leraning_rate" : leraning_rate,
            "gamma" : gamma,
        }
        self.start_params = start_params
        # ベイズ最適化実行
        study = optuna.create_study(direction="minimize", pruner=optuna.pruners.MedianPruner())
        study.enqueue_trial(self.start_params)
        study.optimize(lambda trial: self.objective(trial), n_trials=self.n_trials)
        self.opt_params = study.best_params
        
        with open(f"{self.directory}/{self.basename}_best_params", 'w') as f:
            for k, v in self.opt_params.items():
                print(f'{k} = {v}', file=f)

# %%
class Modeling:
    def __init__(self, data_processor, opt, directory, basename, n_seed=100):
        self.dp = data_processor
        self.opt = opt
        self.directory = directory
        self.basename = basename
        self.n_seed = n_seed
    
    def search_best_model(self, i):
        
        #複数のseed値で探索
        best_score = 0
        best_seed = 0
        for seed in range(700,1000):
        #for seed in range(1):
            base_params = {"verbosity": 0,
                "objective": "reg:squarederror",
                "eval_metric": "rmse",
                "booster":  "gbtree",
                'n_estimators' : 10000,
                #'random_state' : 714, 
                'random_state' : int(seed)
                }
            
            all_params = dict(**base_params, **self.opt.opt_params) 
            model = xgb.train(params=all_params,
                              dtrain=self.dp.dtrain,
                              num_boost_round=10000,
                              early_stopping_rounds=150, 
                              evals=self.dp.evals, 
                              verbose_eval=False
                             )
            
            
            #Predict
            train_pred = pd.DataFrame(model.predict(self.dp.dtrain), columns=[self.dp.object_variable])
            test_pred = pd.DataFrame(model.predict(self.dp.dtest), columns=[self.dp.object_variable])
            # R2値を表示
            r2_train = r2_score(self.dp.Y_train, train_pred).round(4)
            r2_test = r2_score(self.dp.Y_test, test_pred).round(4)
            
            if r2_test >= best_score:
                best_score = r2_test
                best_seed = seed
                best_params = all_params
                self.best_params = best_params
            print(f'Spliting Data {i} : seed {seed} done, best_seed = {best_seed}, best_score = {best_score}')

        with open(f"{self.directory}/{self.basename}_"+str(i), 'w') as f:
            for k, v in self.best_params.items():
                print(f'{k} = {v}', file=f)

        return best_params

# %%
class ModelSaver:
    def __init__(self, modeler, data_processor, directory, basename):
        self.dp = data_processor
        self.model = modeler
        self.directory = directory
        self.basename = basename

    def save_best_model(self, i):
        best_model = xgb.train(params=self.model.best_params,
                           dtrain=self.dp.dtrain,
                           num_boost_round=10000,
                           early_stopping_rounds=150,
                           evals=self.dp.evals, 
                           verbose_eval=False,
                          )
        with open(f"{self.directory}/{self.basename}_model_{i}.pickle", mode='wb') as f:
            pickle.dump(best_model, f)
        best_model.save_model(f"{self.directory}/{self.basename}_model_{i}.json")
        
        train_pred = pd.DataFrame(best_model.predict(self.dp.dtrain), columns=['pIC50'])
        test_pred = pd.DataFrame(best_model.predict(self.dp.dtest), columns=['pIC50'])
        r2_train = r2_score(self.dp.Y_train, train_pred).round(4)
        r2_test = r2_score(self.dp.Y_test, test_pred).round(4)
        self.train_pred = train_pred
        self.test_pred = test_pred
        self.r2_train = r2_train
        self.r2_test = r2_test
        self.best_model = best_model
        
        
        return train_pred, test_pred, r2_train, r2_test

    def save_yyplot(self, i):
        m1, s1 = self.dp.mean_train_y, self.dp.std_train_y
        m2, s2 = self.dp.mean_test_y, self.dp.std_test_y
        # 説明変数と目的変数のデータ点の散布図をプロット
        fig = plt.figure(figsize=(5,5))
        fig.suptitle(" ", fontsize=15)
        s=np.linspace(2.5, 7.5, 50)
        t = s
        plt.plot(s, t, color='k')
        #scatter
        plt.scatter(m1 + self.train_pred*s1, m1 + self.dp.Y_train*s1, color='blue', marker='.' , label='training set')
        plt.scatter(m2 + self.test_pred*s2, m2 + self.dp.Y_test*s2, color='red', marker='.' , label='test set')
        plt.legend(loc=2, fontsize=14)
        plt.xlabel('pIC50 Pred')  # x軸のラベル
        plt.ylabel('pIC50 Expt')  # y軸のラベル
        #plt.xlim(2.5, 7.5)
        #plt.ylim(2.5, 7.5)
        text1 = f'r2_train={self.r2_train}'
        text2 = f'r2_test={self.r2_test}'
        plt.text(4.9, 3, text1, fontsize="xx-large", color='blue')
        plt.text(4.9, 2.5, text2, fontsize="xx-large", color='red')
        plt.savefig(f"{self.directory}/yy_plot_{self.basename}_"+str(i)+".png")

    def save_shap(self, i):
        # SHAP値を計算するためのexplainerを作成
        explainer = shap.TreeExplainer(
            model = self.best_model,  # 学習済みモデル
            feature_perturbation="interventional"  # 推奨
            )
        # SHAP値を計算
        shap_values = explainer(self.dp.X_train, self.dp.Y_train)

        # 棒グラフで重要度を可視化
        fig2 = plt.figure()   #新しいウィンドウを描画
        fig2.subplots()
        shap.plots.bar(shap_values=shap_values, max_display=10, show=False)
        fig2.savefig(f"{self.directory}/shap_bar_{self.basename}_"+str(i)+".png") # 画像を保存
        
        fig3 = plt.figure()   #新しいウィンドウを描画
        fig3.subplots()
        shap.plots.beeswarm(shap_values=shap_values, max_display=10, show=False)
        fig3.savefig(f"{self.directory}/shap_beeswarm_{self.basename}_"+str(i)+".png", bbox_inches='tight')
        plt.clf()
        plt.close()

# %%
def main():
    desc_set = ['rUV', 'rex', 'rfreq', 'rIR', 'rorb', 'IPv', 'C-S0', 'S0-C', 'EAv',
                  'A-S0', 'S0-A', 'STv', 'T1-S0', 'S0-T1', 'Esolv', 'mu','Vmol', 'B1', 'B2', 'B3', 'MW',
                  '1/dE1', '1/dE2', '1/dE3', '1/dE4', '1/dE5', '1/dE6','1/dE7', '1/dE8', '1/dE9',
                  '1/dE10', '1/dE11', '1/dE12', '1/dE13','1/dE14', '1/dE15', '1/dE16', '1/dE17',
                  '1/dE18', '1/dE19', '1/dE20', '1/dE21', '1/dE22', '1/dE23', '1/dE24', '1/dE25',
                   '1/dE26', '1/dE27', '1/dE28', '1/dE29', '1/dE30']
    object_variable = "pIC50"
    directory = "model_result____"
    basename = "ESI_3"
    train_score = []
    test_score =[]
    bayes_n_trials = 10
    n_seed = 1000
    seed_list = pd.read_csv("../datasets/split_seed_result.csv")["seed"]
    all_data = pd.read_csv("../datasets/231113_a-glucosidase_dataset_all.csv")
    if not os.path.isdir(f"{directory}"):
        os.makedirs(f"{directory}")

    #ここで全データでベイズ最適化
    all_data_processor = DataProcessor(all_data, desc_set, object_variable, split_seed=0)
    opt = Optimization(all_data_processor, directory, basename, n_trials=bayes_n_trials)
    opt.optimize_parameters()
    for i, split_seed in enumerate(seed_list[120:121]):
        data_processor = DataProcessor(all_data, desc_set, object_variable, split_seed=split_seed)
        modeler = Modeling(data_processor,opt, directory, basename, n_seed=n_seed)
        modeler.search_best_model(i)

        saver = ModelSaver(modeler, data_processor, directory, basename)
        _, _, r2_train, r2_test = saver.save_best_model(i)
        train_score.append(r2_train)
        test_score.append(r2_test)
        
        # 図の保存
        saver.save_yyplot(i)
        saver.save_shap(i)

    train_score_df = pd.DataFrame(train_score)
    test_score_df = pd.DataFrame(test_score)
    score_df = pd.concat([train_score_df, test_score_df], axis=1)
    score_df.columns = ['r2_train','r2_test']
    score_df.to_csv(f'{directory}/all_score.csv')

if __name__ == "__main__":
    main()
# Out:
# [I 2023-12-07 21:18:20,359] A new study created in memory with name: no-name-8dd72abc-cbc2-45e5-8ded-b3b625cbfadd
# enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# create_trial is experimental (supported from v2.0.0). The interface can change in the future.
# add_trial is experimental (supported from v2.0.0). The interface can change in the future.
# [I 2023-12-07 21:18:23,994] Trial 0 finished with value: 0.6291796591575679 and parameters: {'max_depth': 6, 'max_leaves': 7, 'colsample_bytree': 0.6765954769686744, 'colsample_bylevel': 0.6620193922219532, 'colsample_bynode': 0.6365965428978061, 'subsample': 0.9057028227580022, 'reg_lambda': 8.038853110510981, 'reg_alpha': 0.027527442350278545, 'leraning_rate': 3.5567452676018396, 'gamma': 0.10011594944813659}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:24,446] Trial 1 finished with value: 0.990767534060345 and parameters: {'max_depth': 4, 'max_leaves': 3, 'colsample_bytree': 0.20254692511415823, 'colsample_bylevel': 0.7044834776890032, 'colsample_bynode': 0.298460350692446, 'subsample': 0.005393262447987879, 'reg_lambda': 0.09099269445518962, 'reg_alpha': 0.07821253202197626, 'leraning_rate': 8.127465911434767, 'gamma': 5.295488914745859}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:26,924] Trial 2 finished with value: 0.794295859745313 and parameters: {'max_depth': 2, 'max_leaves': 3, 'colsample_bytree': 0.28993345056914577, 'colsample_bylevel': 0.9528084587219517, 'colsample_bynode': 0.6666490299597073, 'subsample': 0.4043154043073742, 'reg_lambda': 3.551396155476218, 'reg_alpha': 3.5155179265713095, 'leraning_rate': 9.62586907146206, 'gamma': 5.170130031613999}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:29,252] Trial 3 finished with value: 0.7338399994494876 and parameters: {'max_depth': 4, 'max_leaves': 3, 'colsample_bytree': 0.770155770587598, 'colsample_bylevel': 0.15750096487224022, 'colsample_bynode': 0.27704669217494526, 'subsample': 0.32918499476449015, 'reg_lambda': 4.2814250994887635, 'reg_alpha': 0.1389066051892069, 'leraning_rate': 9.847951895734935, 'gamma': 4.872769164763709}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:30,607] Trial 4 finished with value: 0.7015332837505607 and parameters: {'max_depth': 3, 'max_leaves': 6, 'colsample_bytree': 0.21591159926610443, 'colsample_bylevel': 0.17606511109540368, 'colsample_bynode': 0.2504111560826904, 'subsample': 0.6905080418574435, 'reg_lambda': 0.11983213884379773, 'reg_alpha': 0.8098013441604828, 'leraning_rate': 8.54982125486381, 'gamma': 3.2150004053281873}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:33,612] Trial 5 finished with value: 0.798365927738179 and parameters: {'max_depth': 4, 'max_leaves': 2, 'colsample_bytree': 0.19289895899447482, 'colsample_bylevel': 0.41851923062017293, 'colsample_bynode': 0.4511231545077633, 'subsample': 0.3569072927103424, 'reg_lambda': 8.915914476240522, 'reg_alpha': 0.008044495808914197, 'leraning_rate': 3.8558689878842536, 'gamma': 7.074680121712818}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:35,575] Trial 6 finished with value: 0.7872282566795895 and parameters: {'max_depth': 2, 'max_leaves': 3, 'colsample_bytree': 0.5090381632111823, 'colsample_bylevel': 0.24153814623446335, 'colsample_bynode': 0.11746274680405538, 'subsample': 0.9076638255992258, 'reg_lambda': 5.629016704151609, 'reg_alpha': 0.00021744442667649629, 'leraning_rate': 8.907780741219849, 'gamma': 8.2147071437277}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:37,095] Trial 7 finished with value: 0.7552411235125364 and parameters: {'max_depth': 2, 'max_leaves': 2, 'colsample_bytree': 0.19726431920688434, 'colsample_bylevel': 0.4424237719131726, 'colsample_bynode': 0.9211628988868316, 'subsample': 0.8098948554754166, 'reg_lambda': 0.013026972262615882, 'reg_alpha': 0.0005164553766888697, 'leraning_rate': 4.238401713927294, 'gamma': 7.417948870140764}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:38,967] Trial 8 finished with value: 0.7645470765223797 and parameters: {'max_depth': 6, 'max_leaves': 3, 'colsample_bytree': 0.8412687126463566, 'colsample_bylevel': 0.656197833280344, 'colsample_bynode': 0.1988161422334422, 'subsample': 0.3870304177120767, 'reg_lambda': 0.0008251692296789855, 'reg_alpha': 0.3700950725969959, 'leraning_rate': 5.966103194047489, 'gamma': 8.392231701063443}. Best is trial 0 with value: 0.6291796591575679.
# [I 2023-12-07 21:18:42,585] Trial 9 finished with value: 0.7529305632742335 and parameters: {'max_depth': 6, 'max_leaves': 3, 'colsample_bytree': 0.8486323146043699, 'colsample_bylevel': 0.5271985220380591, 'colsample_bynode': 0.6696824201749062, 'subsample': 0.8077574270256402, 'reg_lambda': 0.018159145975633346, 'reg_alpha': 0.3783967073025725, 'leraning_rate': 7.39222465854505, 'gamma': 8.358804652063323}. Best is trial 0 with value: 0.6291796591575679.
# Spliting Data 0 : seed 700 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 701 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 702 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 703 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 704 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 705 done, best_seed = 700, best_score = 0.7875
# Spliting Data 0 : seed 706 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 707 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 708 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 709 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 710 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 711 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 712 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 713 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 714 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 715 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 716 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 717 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 718 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 719 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 720 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 721 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 722 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 723 done, best_seed = 706, best_score = 0.8137
# Spliting Data 0 : seed 724 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 725 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 726 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 727 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 728 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 729 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 730 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 731 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 732 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 733 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 734 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 735 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 736 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 737 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 738 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 739 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 740 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 741 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 742 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 743 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 744 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 745 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 746 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 747 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 748 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 749 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 750 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 751 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 752 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 753 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 754 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 755 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 756 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 757 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 758 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 759 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 760 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 761 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 762 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 763 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 764 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 765 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 766 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 767 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 768 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 769 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 770 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 771 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 772 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 773 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 774 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 775 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 776 done, best_seed = 724, best_score = 0.8298
# Spliting Data 0 : seed 777 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 778 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 779 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 780 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 781 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 782 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 783 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 784 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 785 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 786 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 787 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 788 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 789 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 790 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 791 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 792 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 793 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 794 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 795 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 796 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 797 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 798 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 799 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 800 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 801 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 802 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 803 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 804 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 805 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 806 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 807 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 808 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 809 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 810 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 811 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 812 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 813 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 814 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 815 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 816 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 817 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 818 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 819 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 820 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 821 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 822 done, best_seed = 777, best_score = 0.8302
# Spliting Data 0 : seed 823 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 824 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 825 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 826 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 827 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 828 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 829 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 830 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 831 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 832 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 833 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 834 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 835 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 836 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 837 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 838 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 839 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 840 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 841 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 842 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 843 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 844 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 845 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 846 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 847 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 848 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 849 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 850 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 851 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 852 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 853 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 854 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 855 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 856 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 857 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 858 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 859 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 860 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 861 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 862 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 863 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 864 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 865 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 866 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 867 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 868 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 869 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 870 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 871 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 872 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 873 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 874 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 875 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 876 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 877 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 878 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 879 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 880 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 881 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 882 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 883 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 884 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 885 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 886 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 887 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 888 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 889 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 890 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 891 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 892 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 893 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 894 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 895 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 896 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 897 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 898 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 899 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 900 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 901 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 902 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 903 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 904 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 905 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 906 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 907 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 908 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 909 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 910 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 911 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 912 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 913 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 914 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 915 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 916 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 917 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 918 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 919 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 920 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 921 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 922 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 923 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 924 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 925 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 926 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 927 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 928 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 929 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 930 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 931 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 932 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 933 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 934 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 935 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 936 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 937 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 938 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 939 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 940 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 941 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 942 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 943 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 944 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 945 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 946 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 947 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 948 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 949 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 950 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 951 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 952 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 953 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 954 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 955 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 956 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 957 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 958 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 959 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 960 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 961 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 962 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 963 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 964 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 965 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 966 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 967 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 968 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 969 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 970 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 971 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 972 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 973 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 974 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 975 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 976 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 977 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 978 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 979 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 980 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 981 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 982 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 983 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 984 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 985 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 986 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 987 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 988 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 989 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 990 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 991 done, best_seed = 823, best_score = 0.8349
# Spliting Data 0 : seed 992 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 993 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 994 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 995 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 996 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 997 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 998 done, best_seed = 992, best_score = 0.8459
# Spliting Data 0 : seed 999 done, best_seed = 992, best_score = 0.8459

# %%
seed_list[120]
# Out:
# 40884

# %%
seed_list = pd.read_csv("../datasets/split_seed_result.csv")
seed_list
# Out:
#       seed   mean_difference  variance_difference      products
# 0    36464      5.257066e-07             0.056481  2.969253e-08
# 1    40915      5.501928e-04             0.000056  3.065019e-08
# 2    49533      2.462007e-04             0.000158  3.885580e-08
# 3    57730      3.862267e-02             0.000002  5.909065e-08
# 4    16140      6.691175e-05             0.001531  1.024134e-07
# ..     ...               ...                  ...           ...
# 995  75302      3.015978e-04             0.151095  4.556977e-05
# 996  68477      4.789591e-03             0.009517  4.558278e-05
# 997  42434      1.332279e-01             0.000343  4.567203e-05
# 998  63297      4.000875e-04             0.114282  4.572279e-05
# 999  64857      9.949221e-02             0.000460  4.572676e-05
#
# [1000 rows x 4 columns]
